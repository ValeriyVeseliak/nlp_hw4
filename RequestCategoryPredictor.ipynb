# %%
from gensim.models import KeyedVectors
from langdetect import detect
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import pandas as pd
import codecs
import nltk
import os
import re

import warnings
warnings.filterwarnings('ignore')

# %%
def read_requests_data():
    all_requests = []
    for filename in os.listdir("./1551/"):
        category = filename[:-4]
        with open("./1551/" + filename) as f:
            file_content = f.read()
            file_requests = re.split(r'\n{2,}\d{6,}\n', file_content)
            for request in file_requests:
                request_split = re.split(r'\n', request)
                if request_split and request_split[0] != "":
                    if re.match("^\d{6,}$", request_split[0].strip()):
                        request_text = " ".join(request_split[1:])
                    else:
                        request_text = " ".join(request_split)
                    
                    request_text = request_text.replace("\n", " ")\
                            .replace("[\d\+\\\/\-\.]+", " ").strip().lower()
                    try:
                        if detect(request_text) != 'uk':
                            continue
                        all_requests.append((request_text, category))
                    except Exception:
                        print("Not detected")
                        print("-----------------------")
                        print(request_split)
                        
    return pd.DataFrame(all_requests, columns=["request", "category"])
                
def read_embeddings():
    emgeddings = KeyedVectors.load_word2vec_format("./news.lowercased.tokenized.word2vec.300d", binary=False)
    return emgeddings

# %%
embeddings = read_embeddings()

# %%
def get_stopwords():
    with open("./stopwords.txt") as f:
        return f.readlines()

# %%
requests_data = read_requests_data()
# Out:
# Not detected
# -----------------------
# ['2847929']
# Not detected
# -----------------------
# ['2839007']

# %%
requests_data.count()
# Out:
# request     62078
# category    62078
# dtype: int64

# %%
requests_data.head()
# Out:
#                                              request  \
# 0  згідно даних сайту містобудівного кадастру м. ...
# 1  добрий день.  прохання навести порядок з рекла...
# 2  скарга. на нижній набережній, що йде  вздовж в...
# 3  на огородженні мосту(каховский путепровод №1) ...
# 4  прошу перевірити законність конструкцій та вив...
#
#                                category
# 0  Контроль-за-станом-рекламних-засобів
# 1  Контроль-за-станом-рекламних-засобів
# 2  Контроль-за-станом-рекламних-засобів
# 3  Контроль-за-станом-рекламних-засобів
# 4  Контроль-за-станом-рекламних-засобів

# %%
def cleanupDoc(s):
    stopset = set(get_stopwords())
    tokens = nltk.word_tokenize(s)
    cleanup = [token.lower() for token in tokens if token.lower() not in stopset and  len(token)>2]
    return cleanup

# %%
requests_data['cleaned_request'] = requests_data['request'].apply(cleanupDoc)

# %%
def request_to_vector(req):
    req_words_embeddings=[]
    for word in req:
        # filter out numbers and links
        if re.match(r"^[\d\-\.\#\№\\\/\s]+$", word) or word.startswith("http") or word.startswith("//"):
            continue
        try:
            emb = embeddings.get_vector(word)
            req_words_embeddings.append(emb)
        except:
            continue
    req_words_embeddings = np.array(req_words_embeddings)
    return np.sum(req_words_embeddings, axis=0).reshape(-1)

# %%
requests_data['request_embeddings'] = requests_data['cleaned_request'].apply(request_to_vector)

# %%
from sklearn.preprocessing import LabelEncoder


le = LabelEncoder()
le.fit(requests_data['category'].unique())
requests_data['category_encoded'] = le.transform(requests_data['category'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(requests_data['request_embeddings'].to_list(), 
                                                    requests_data['category_encoded'].to_list(), 
                                                    test_size=0.3, random_state=1, 
                                                    stratify=requests_data['category_encoded'].to_list())

# %%
knn_model = KNeighborsClassifier(n_neighbors=188, metric='cosine')
knn_model.fit(X=X_train, y=y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='cosine',
#            metric_params=None, n_jobs=1, n_neighbors=188, p=2,
#            weights='uniform')

# %%
predictions = knn_model.predict(X_test)

# %%
from sklearn.metrics import f1_score, classification_report

print("F1 score =  ", f1_score(y_test, predictions, average="micro"))
# Out:
# F1 score =   0.3562896804046056

# %%
print(classification_report(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.30      0.03      0.06        93
#           1       0.30      0.40      0.34       209
#           2       0.00      0.00      0.00        84
#           3       0.00      0.00      0.00        22
#           4       0.00      0.00      0.00        25
#           5       0.00      0.00      0.00        28
#           6       0.00      0.00      0.00        15
#           7       0.28      0.71      0.40       191
#           8       1.00      0.13      0.23        38
#           9       1.00      0.07      0.14        27
#          10       0.00      0.00      0.00        24
#          11       0.35      0.09      0.15        96
#          12       0.00      0.00      0.00        26
#          13       0.84      0.42      0.56        38
#          14       0.67      0.03      0.06        65
#          15       0.00      0.00      0.00        17
#          16       0.48      0.25      0.33       123
#          17       0.68      0.12      0.20       130
#          18       0.00      0.00      0.00        87
#          19       0.00      0.00      0.00        41
#          20       0.54      0.11      0.19        62
#          21       0.54      0.08      0.15        83
#          22       0.50      0.18      0.27       105
#          23       0.00      0.00      0.00        56
#          24       0.57      0.40      0.47       109
#          25       0.25      0.36      0.30       143
#          26       0.37      0.12      0.18        57
#          27       0.00      0.00      0.00        28
#          28       0.38      0.37      0.37       388
#          29       0.00      0.00      0.00       234
#          30       0.00      0.00      0.00        77
#          31       0.00      0.00      0.00        34
#          32       0.50      0.02      0.04        50
#          33       0.38      0.95      0.54      1970
#          34       0.00      0.00      0.00        16
#          35       0.00      0.00      0.00        21
#          36       0.00      0.00      0.00        71
#          37       0.00      0.00      0.00        43
#          38       0.54      0.55      0.55       942
#          39       0.57      0.08      0.14       297
#          40       0.00      0.00      0.00        25
#          41       0.63      0.07      0.13       162
#          42       0.38      0.50      0.43       379
#          43       0.00      0.00      0.00        21
#          44       0.83      0.20      0.32       248
#          45       0.00      0.00      0.00        45
#          46       0.00      0.00      0.00        20
#          47       1.00      0.05      0.10        37
#          48       0.00      0.00      0.00        22
#          49       0.00      0.00      0.00        34
#          50       0.37      0.10      0.16       138
#          51       0.00      0.00      0.00        78
#          52       0.82      0.16      0.27        56
#          53       0.75      0.23      0.35        40
#          54       0.00      0.00      0.00        29
#          55       0.88      0.14      0.24        51
#          56       0.67      0.06      0.11        35
#          57       0.88      0.37      0.52        19
#          58       0.43      0.58      0.50        84
#          59       0.00      0.00      0.00        20
#          60       1.00      0.05      0.09        61
#          61       0.50      0.01      0.02        95
#          62       0.90      0.45      0.60        20
#          63       1.00      0.05      0.09        21
#          64       0.71      0.15      0.24        34
#          65       0.39      0.09      0.14       105
#          66       0.00      0.00      0.00        75
#          67       0.00      0.00      0.00        82
#          68       0.50      0.56      0.53       364
#          69       0.00      0.00      0.00        40
#          70       0.00      0.00      0.00        17
#          71       0.00      0.00      0.00        39
#          72       0.46      0.41      0.43       335
#          73       0.57      0.13      0.21       192
#          74       0.83      0.61      0.70        41
#          75       0.41      0.20      0.27        61
#          76       0.71      0.37      0.48       115
#          77       0.00      0.00      0.00        29
#          78       1.00      0.04      0.08        47
#          79       0.00      0.00      0.00        44
#          80       0.00      0.00      0.00        25
#          81       0.00      0.00      0.00        19
#          82       0.00      0.00      0.00        16
#          83       0.00      0.00      0.00        18
#          84       0.25      0.02      0.04        53
#          85       0.00      0.00      0.00        18
#          86       0.00      0.00      0.00        23
#          87       0.25      0.27      0.26        55
#          88       0.00      0.00      0.00        25
#          89       0.00      0.00      0.00        20
#          90       0.00      0.00      0.00        44
#          91       0.00      0.00      0.00        17
#          92       0.00      0.00      0.00        24
#          93       1.00      0.03      0.06        35
#          94       0.45      0.02      0.04       223
#          95       1.00      0.02      0.04        53
#          96       0.00      0.00      0.00        21
#          97       0.00      0.00      0.00        17
#          98       0.00      0.00      0.00        56
#          99       0.23      0.24      0.23       105
#         100       0.00      0.00      0.00        16
#         101       0.00      0.00      0.00        71
#         102       0.00      0.00      0.00        27
#         103       0.00      0.00      0.00        66
#         104       0.26      0.78      0.39       663
#         105       0.19      0.15      0.17        95
#         106       0.00      0.00      0.00        19
#         107       0.00      0.00      0.00        25
#         108       0.00      0.00      0.00        25
#         109       0.53      0.33      0.41       193
#         110       0.00      0.00      0.00        25
#         111       0.00      0.00      0.00        33
#         112       0.00      0.00      0.00        31
#         113       0.00      0.00      0.00        25
#         114       0.40      0.61      0.48       331
#         115       0.00      0.00      0.00        26
#         116       0.00      0.00      0.00        15
#         117       0.70      0.38      0.49        50
#         118       0.00      0.00      0.00        35
#         119       0.38      0.02      0.04       155
#         120       0.67      0.08      0.15        24
#         121       0.00      0.00      0.00        42
#         122       0.00      0.00      0.00        44
#         123       0.00      0.00      0.00        37
#         124       0.00      0.00      0.00        40
#         125       0.29      0.03      0.05        79
#         126       0.00      0.00      0.00        17
#         127       0.00      0.00      0.00        35
#         128       0.00      0.00      0.00        22
#         129       1.00      0.03      0.05        39
#         130       0.00      0.00      0.00        25
#         131       0.00      0.00      0.00        29
#         132       0.00      0.00      0.00        40
#         133       0.00      0.00      0.00        55
#         134       0.00      0.00      0.00        30
#         135       0.25      0.16      0.20       234
#         136       0.00      0.00      0.00        39
#         137       0.33      0.60      0.43       600
#         138       0.00      0.00      0.00        19
#         139       0.18      0.32      0.23       297
#         140       0.00      0.00      0.00        43
#         141       0.00      0.00      0.00        61
#         142       0.00      0.00      0.00        47
#         143       0.00      0.00      0.00        19
#         144       0.00      0.00      0.00        54
#         145       0.00      0.00      0.00        14
#         146       0.50      0.06      0.11        47
#         147       0.00      0.00      0.00        25
#         148       1.00      0.03      0.06        32
#         149       0.29      0.54      0.38        61
#         150       0.43      0.38      0.40       202
#         151       0.00      0.00      0.00        41
#         152       0.28      0.57      0.37       363
#         153       0.82      0.17      0.28        53
#         154       0.13      0.03      0.04        74
#         155       0.00      0.00      0.00        34
#         156       0.00      0.00      0.00        75
#         157       0.00      0.00      0.00        19
#         158       0.00      0.00      0.00        52
#         159       0.00      0.00      0.00        39
#         160       0.00      0.00      0.00        49
#         161       1.00      0.01      0.02        80
#         162       0.55      0.43      0.48       145
#         163       0.00      0.00      0.00       145
#         164       0.00      0.00      0.00        45
#         165       0.00      0.00      0.00        28
#         166       0.00      0.00      0.00        44
#         167       0.00      0.00      0.00        23
#         168       0.55      0.23      0.33       134
#         169       0.00      0.00      0.00        21
#         170       0.00      0.00      0.00        20
#         171       0.00      0.00      0.00        17
#         172       0.50      0.01      0.01       142
#         173       0.00      0.00      0.00       138
#         174       0.00      0.00      0.00        20
#         175       0.45      0.20      0.28       392
#         176       0.00      0.00      0.00        65
#         177       0.00      0.00      0.00        30
#         178       0.33      0.13      0.18        63
#         179       0.00      0.00      0.00        35
#         180       0.29      0.80      0.42      1089
#         181       0.00      0.00      0.00        55
#         182       0.00      0.00      0.00        25
#         183       0.00      0.00      0.00        20
#         184       0.44      0.05      0.10        74
#         185       0.52      0.19      0.28       186
#         186       0.00      0.00      0.00        57
#         187       0.00      0.00      0.00        24
#
# avg / total       0.34      0.36      0.27     18586

# %% [markdown]
# As we can see, the f1 score for KNN classifier with cosine similarity metric is only 0.36.  But as we can see, that lot of categories has 0 recall and precision. We can try to filter out categories without enough requests represented.

# %%
requests_data.groupby("category").count()
# Out:
#                                                     request  cleaned_request  \
# category
# Інші-Подяки                                             310              310
# Інші-технічні-недоліки-стану-ліфту                      696              696
# Аварійний--травмонебезпечний-стан-утримання-об-...      280              280
# Бажаючі-отримати--Картки-киянина--КК--                   72               72
# Будівництво--дооблаштування-спортивних-майданчиків       82               82
# Будівництво-АЗС                                          93               93
# Будівництво-в-нічний-час                                 51               51
# Будівництво-дооблаштування-дитячого-майданчику          636              636
# Будівництво-та-реконструкція-об-єктів-освіти            128              128
# Взаємовідносини-з-сусідами                               91               91
# Вивезення--утилізація-твердих-та-негабаритних-в...       81               81
# Видалення-аварійних--пошкоджених-хворобами-дерев        319              319
# Видача-розрахункових-книжок--квитанцій--довідок          88               88
# Вилов-безпритульних-тварин                              126              126
# Вирізування--кронування--гілля-дерев                    215              215
# Виток-холодної-води-на-поверхню                          57               57
# Вологе-прибирання-приміщень                             410              410
# Встановлення-лічильників-на-опалення-                   433              433
# Встановлення-огородження-зеленої-зони                   289              289
# Встановлення-пандусів                                   135              135
# Встановлення-світлофора                                 206              206
# Встановлення-сигнальних-стовпчиків--бар-єрних-о...      276              276
# Встановлення-сміттєвих-контейнерів-та-урн-для-с...      349              349
# Встановлення-та-демонтаж-лавочок                        188              188
# Встановлення-та-експлуатація-дорожніх-знаків            364              364
# Встановлення-та-експлуатація-лічильників-на-вод...      476              476
# Встановлення-та-експлуатація-пристроїв-примусов...      189              189
# Встановлення-та-експлуатація-шлагбаумів                  95               95
# Відновлення-благоустрою-після-вик--планових-ава...     1294             1294
# Відсутнє-ХВП                                            779              779
# ...                                                     ...              ...
# Ремонт-та-обслуговування-ґанків                         172              172
# Ремонт-теплотрас--підключення                           129              129
# Ремонт-фасаду-будинку                                   163              163
# Ремонт-і-обслуговування-сміттєпроводів-та-смітт...      265              265
# Робота-світлофора                                       483              483
# Робота-циркуляційної-системи                            482              482
# Розміщення-паркувальних-майданчиків                     150              150
# Розрахунки--нарахування-та-перерахунок-субсидій          92               92
# Садіння-нових-дерев-і-кущів                             148              148
# Санітарний-стан-проїжджих-частин                         77               77
# Скління-та-ремонт-вікон-на-сходових-клітинах-           445              445
# Скошування-трави                                         70               70
# Спалювання-сміття--листя--гілок--відходів--тощо-         68               68
# Стан-зливосточних-систем-проїжджих-частин-та-тр...       56               56
# Стихійне-сміттєзвалище                                  473              473
# Технічне-обслуговування-систем-тепло---водопост...      460              460
# Технічний-стан-мостів-та-шляхопроводів                   66               66
# Технічний-стан-проїжджих-частин-вулиць-та-троту...     1308             1308
# Технічний-стан-підземних-пішохідних-переходів           217              217
# Технічний-стан-пішохідниїх-доріжок--сходів-з-бе...      101              101
# Удосконалення-організації-дорожнього-руху               211              211
# Укладання-договорів-з-обслуговуючими-організаціями      115              115
# Укладання-та-ремонт-асфальтного-покриття               3630             3630
# Укладання-та-ремонт-тротуарної-плитки--брущатки-        184              184
# Укладання-та-технічний-стан-бордюрного-каменю            82               82
# Утримання-номерних-знаків-і-табличок-з-назвами-...       68               68
# Утримання-парків-та-лісопарків-у-місті-Києві            245              245
# Утримання-підвалів--колясочних-технічних-поверхів       621              621
# Утримання-та-облаштування-клумб-та-газонів              189              189
# Утримання-інформаційних-дошок-та--розклеювання-...       79               79
#
#                                                     request_embeddings  \
# category
# Інші-Подяки                                                        310
# Інші-технічні-недоліки-стану-ліфту                                 696
# Аварійний--травмонебезпечний-стан-утримання-об-...                 280
# Бажаючі-отримати--Картки-киянина--КК--                              72
# Будівництво--дооблаштування-спортивних-майданчиків                  82
# Будівництво-АЗС                                                     93
# Будівництво-в-нічний-час                                            51
# Будівництво-дооблаштування-дитячого-майданчику                     636
# Будівництво-та-реконструкція-об-єктів-освіти                       128
# Взаємовідносини-з-сусідами                                          91
# Вивезення--утилізація-твердих-та-негабаритних-в...                  81
# Видалення-аварійних--пошкоджених-хворобами-дерев                   319
# Видача-розрахункових-книжок--квитанцій--довідок                     88
# Вилов-безпритульних-тварин                                         126
# Вирізування--кронування--гілля-дерев                               215
# Виток-холодної-води-на-поверхню                                     57
# Вологе-прибирання-приміщень                                        410
# Встановлення-лічильників-на-опалення-                              433
# Встановлення-огородження-зеленої-зони                              289
# Встановлення-пандусів                                              135
# Встановлення-світлофора                                            206
# Встановлення-сигнальних-стовпчиків--бар-єрних-о...                 276
# Встановлення-сміттєвих-контейнерів-та-урн-для-с...                 349
# Встановлення-та-демонтаж-лавочок                                   188
# Встановлення-та-експлуатація-дорожніх-знаків                       364
# Встановлення-та-експлуатація-лічильників-на-вод...                 476
# Встановлення-та-експлуатація-пристроїв-примусов...                 189
# Встановлення-та-експлуатація-шлагбаумів                             95
# Відновлення-благоустрою-після-вик--планових-ава...                1294
# Відсутнє-ХВП                                                       779
# ...                                                                ...
# Ремонт-та-обслуговування-ґанків                                    172
# Ремонт-теплотрас--підключення                                      129
# Ремонт-фасаду-будинку                                              163
# Ремонт-і-обслуговування-сміттєпроводів-та-смітт...                 265
# Робота-світлофора                                                  483
# Робота-циркуляційної-системи                                       482
# Розміщення-паркувальних-майданчиків                                150
# Розрахунки--нарахування-та-перерахунок-субсидій                     92
# Садіння-нових-дерев-і-кущів                                        148
# Санітарний-стан-проїжджих-частин                                    77
# Скління-та-ремонт-вікон-на-сходових-клітинах-                      445
# Скошування-трави                                                    70
# Спалювання-сміття--листя--гілок--відходів--тощо-                    68
# Стан-зливосточних-систем-проїжджих-частин-та-тр...                  56
# Стихійне-сміттєзвалище                                             473
# Технічне-обслуговування-систем-тепло---водопост...                 460
# Технічний-стан-мостів-та-шляхопроводів                              66
# Технічний-стан-проїжджих-частин-вулиць-та-троту...                1308
# Технічний-стан-підземних-пішохідних-переходів                      217
# Технічний-стан-пішохідниїх-доріжок--сходів-з-бе...                 101
# Удосконалення-організації-дорожнього-руху                          211
# Укладання-договорів-з-обслуговуючими-організаціями                 115
# Укладання-та-ремонт-асфальтного-покриття                          3630
# Укладання-та-ремонт-тротуарної-плитки--брущатки-                   184
# Укладання-та-технічний-стан-бордюрного-каменю                       82
# Утримання-номерних-знаків-і-табличок-з-назвами-...                  68
# Утримання-парків-та-лісопарків-у-місті-Києві                       245
# Утримання-підвалів--колясочних-технічних-поверхів                  621
# Утримання-та-облаштування-клумб-та-газонів                         189
# Утримання-інформаційних-дошок-та--розклеювання-...                  79
#
#                                                     is_request_embeddings_empty  \
# category
# Інші-Подяки                                                                 310
# Інші-технічні-недоліки-стану-ліфту                                          696
# Аварійний--травмонебезпечний-стан-утримання-об-...                          280
# Бажаючі-отримати--Картки-киянина--КК--                                       72
# Будівництво--дооблаштування-спортивних-майданчиків                           82
# Будівництво-АЗС                                                              93
# Будівництво-в-нічний-час                                                     51
# Будівництво-дооблаштування-дитячого-майданчику                              636
# Будівництво-та-реконструкція-об-єктів-освіти                                128
# Взаємовідносини-з-сусідами                                                   91
# Вивезення--утилізація-твердих-та-негабаритних-в...                           81
# Видалення-аварійних--пошкоджених-хворобами-дерев                            319
# Видача-розрахункових-книжок--квитанцій--довідок                              88
# Вилов-безпритульних-тварин                                                  126
# Вирізування--кронування--гілля-дерев                                        215
# Виток-холодної-води-на-поверхню                                              57
# Вологе-прибирання-приміщень                                                 410
# Встановлення-лічильників-на-опалення-                                       433
# Встановлення-огородження-зеленої-зони                                       289
# Встановлення-пандусів                                                       135
# Встановлення-світлофора                                                     206
# Встановлення-сигнальних-стовпчиків--бар-єрних-о...                          276
# Встановлення-сміттєвих-контейнерів-та-урн-для-с...                          349
# Встановлення-та-демонтаж-лавочок                                            188
# Встановлення-та-експлуатація-дорожніх-знаків                                364
# Встановлення-та-експлуатація-лічильників-на-вод...                          476
# Встановлення-та-експлуатація-пристроїв-примусов...                          189
# Встановлення-та-експлуатація-шлагбаумів                                      95
# Відновлення-благоустрою-після-вик--планових-ава...                         1294
# Відсутнє-ХВП                                                                779
# ...                                                                         ...
# Ремонт-та-обслуговування-ґанків                                             172
# Ремонт-теплотрас--підключення                                               129
# Ремонт-фасаду-будинку                                                       163
# Ремонт-і-обслуговування-сміттєпроводів-та-смітт...                          265
# Робота-світлофора                                                           483
# Робота-циркуляційної-системи                                                482
# Розміщення-паркувальних-майданчиків                                         150
# Розрахунки--нарахування-та-перерахунок-субсидій                              92
# Садіння-нових-дерев-і-кущів                                                 148
# Санітарний-стан-проїжджих-частин                                             77
# Скління-та-ремонт-вікон-на-сходових-клітинах-                               445
# Скошування-трави                                                             70
# Спалювання-сміття--листя--гілок--відходів--тощо-                             68
# Стан-зливосточних-систем-проїжджих-частин-та-тр...                           56
# Стихійне-сміттєзвалище                                                      473
# Технічне-обслуговування-систем-тепло---водопост...                          460
# Технічний-стан-мостів-та-шляхопроводів                                       66
# Технічний-стан-проїжджих-частин-вулиць-та-троту...                         1308
# Технічний-стан-підземних-пішохідних-переходів                               217
# Технічний-стан-пішохідниїх-доріжок--сходів-з-бе...                          101
# Удосконалення-організації-дорожнього-руху                                   211
# Укладання-договорів-з-обслуговуючими-організаціями                          115
# Укладання-та-ремонт-асфальтного-покриття                                   3630
# Укладання-та-ремонт-тротуарної-плитки--брущатки-                            184
# Укладання-та-технічний-стан-бордюрного-каменю                                82
# Утримання-номерних-знаків-і-табличок-з-назвами-...                           68
# Утримання-парків-та-лісопарків-у-місті-Києві                                245
# Утримання-підвалів--колясочних-технічних-поверхів                           621
# Утримання-та-облаштування-клумб-та-газонів                                  189
# Утримання-інформаційних-дошок-та--розклеювання-...                           79
#
#                                                     category_encoded
# category
# Інші-Подяки                                                      310
# Інші-технічні-недоліки-стану-ліфту                               696
# Аварійний--травмонебезпечний-стан-утримання-об-...               280
# Бажаючі-отримати--Картки-киянина--КК--                            72
# Будівництво--дооблаштування-спортивних-майданчиків                82
# Будівництво-АЗС                                                   93
# Будівництво-в-нічний-час                                          51
# Будівництво-дооблаштування-дитячого-майданчику                   636
# Будівництво-та-реконструкція-об-єктів-освіти                     128
# Взаємовідносини-з-сусідами                                        91
# Вивезення--утилізація-твердих-та-негабаритних-в...                81
# Видалення-аварійних--пошкоджених-хворобами-дерев                 319
# Видача-розрахункових-книжок--квитанцій--довідок                   88
# Вилов-безпритульних-тварин                                       126
# Вирізування--кронування--гілля-дерев                             215
# Виток-холодної-води-на-поверхню                                   57
# Вологе-прибирання-приміщень                                      410
# Встановлення-лічильників-на-опалення-                            433
# Встановлення-огородження-зеленої-зони                            289
# Встановлення-пандусів                                            135
# Встановлення-світлофора                                          206
# Встановлення-сигнальних-стовпчиків--бар-єрних-о...               276
# Встановлення-сміттєвих-контейнерів-та-урн-для-с...               349
# Встановлення-та-демонтаж-лавочок                                 188
# Встановлення-та-експлуатація-дорожніх-знаків                     364
# Встановлення-та-експлуатація-лічильників-на-вод...               476
# Встановлення-та-експлуатація-пристроїв-примусов...               189
# Встановлення-та-експлуатація-шлагбаумів                           95
# Відновлення-благоустрою-після-вик--планових-ава...              1294
# Відсутнє-ХВП                                                     779
# ...                                                              ...
# Ремонт-та-обслуговування-ґанків                                  172
# Ремонт-теплотрас--підключення                                    129
# Ремонт-фасаду-будинку                                            163
# Ремонт-і-обслуговування-сміттєпроводів-та-смітт...               265
# Робота-світлофора                                                483
# Робота-циркуляційної-системи                                     482
# Розміщення-паркувальних-майданчиків                              150
# Розрахунки--нарахування-та-перерахунок-субсидій                   92
# Садіння-нових-дерев-і-кущів                                      148
# Санітарний-стан-проїжджих-частин                                  77
# Скління-та-ремонт-вікон-на-сходових-клітинах-                    445
# Скошування-трави                                                  70
# Спалювання-сміття--листя--гілок--відходів--тощо-                  68
# Стан-зливосточних-систем-проїжджих-частин-та-тр...                56
# Стихійне-сміттєзвалище                                           473
# Технічне-обслуговування-систем-тепло---водопост...               460
# Технічний-стан-мостів-та-шляхопроводів                            66
# Технічний-стан-проїжджих-частин-вулиць-та-троту...              1308
# Технічний-стан-підземних-пішохідних-переходів                    217
# Технічний-стан-пішохідниїх-доріжок--сходів-з-бе...               101
# Удосконалення-організації-дорожнього-руху                        211
# Укладання-договорів-з-обслуговуючими-організаціями               115
# Укладання-та-ремонт-асфальтного-покриття                        3630
# Укладання-та-ремонт-тротуарної-плитки--брущатки-                 184
# Укладання-та-технічний-стан-бордюрного-каменю                     82
# Утримання-номерних-знаків-і-табличок-з-назвами-...                68
# Утримання-парків-та-лісопарків-у-місті-Києві                     245
# Утримання-підвалів--колясочних-технічних-поверхів                621
# Утримання-та-облаштування-клумб-та-газонів                       189
# Утримання-інформаційних-дошок-та--розклеювання-...                79
#
# [188 rows x 5 columns]

# %%
s = requests_data.groupby("category").count()['request']
categories_to_use = s[s > 500].index.to_list()

requests_data = requests_data[requests_data['category'].isin(categories_to_use)]
requests_data.count()
# Out:
# request                        36133
# category                       36133
# cleaned_request                36133
# request_embeddings             36133
# is_request_embeddings_empty    36133
# category_encoded               36133
# request_tfidf                  36133
# dtype: int64

# %%
le = LabelEncoder()
le.fit(requests_data['category'].unique())
requests_data['category_encoded'] = le.transform(requests_data['category'])
X_train, X_test, y_train, y_test = train_test_split(requests_data['request_embeddings'].to_list(), 
                                                    requests_data['category_encoded'].to_list(), 
                                                    test_size=0.3, random_state=1, 
                                                    stratify=requests_data['category_encoded'].to_list())

knn_model = KNeighborsClassifier(n_neighbors=26, metric='cosine')
knn_model.fit(X=X_train, y=y_train)
predictions = knn_model.predict(X_test)
print("F1 score =  ", f1_score(y_test, predictions, average="micro"))
print(classification_report(y_test, predictions))
# Out:
# F1 score =   0.5955719557195572
#              precision    recall  f1-score   support
#
#           0       0.44      0.47      0.45       209
#           1       0.66      0.80      0.72       191
#           2       0.50      0.46      0.48       388
#           3       0.75      0.09      0.16       234
#           4       0.61      0.92      0.73      1970
#           5       0.61      0.63      0.62       942
#           6       0.60      0.18      0.28       297
#           7       0.44      0.17      0.24       162
#           8       0.51      0.53      0.52       379
#           9       0.88      0.42      0.57       248
#          10       0.68      0.60      0.64       364
#          11       0.64      0.56      0.60       335
#          12       0.65      0.32      0.43       192
#          13       0.36      0.13      0.20       223
#          14       0.61      0.79      0.69       663
#          15       0.69      0.36      0.48       193
#          16       0.72      0.67      0.69       331
#          17       0.55      0.10      0.17       155
#          18       0.70      0.39      0.50       234
#          19       0.69      0.69      0.69       600
#          20       0.44      0.37      0.41       297
#          21       0.65      0.52      0.58       202
#          22       0.49      0.60      0.54       363
#          23       0.59      0.28      0.38       393
#          24       0.54      0.74      0.63      1089
#          25       0.54      0.20      0.30       186
#
# avg / total       0.60      0.60      0.57     10840

# %% [markdown]
# As we can see for categories with enough number of requests we can see much better accuracy with f1 score 0.59. So for first 26 categories with more than 500 requests we have accuracy 0.59.
#
#
# Next we are going to add some enhancements to improve the accuracy.

# %% [markdown]
# ### Improvements

# %% [markdown]
# As we actually did already previous preprocessing and filtering out documents with small number of elements and filtered out numbers, links, etc we are going to add lemmatization with lemmatized embeddings, use TF-IDF and try to use another models, like SVM, RandomForest and Logistic Regression.

# %% [markdown]
# ##### TF-IDF

# %% [markdown]
# As it is super hard for my laptop to compute TF-IDF and KNN for all 36 thousands of records, i will take a half of it and try to calculate it on smaller amount of data

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(min_df=0.0, dtype=np.float32)

X_train, X_test, y_train, y_test = train_test_split(requests_data['cleaned_request'], 
                                                    requests_data['category_encoded'], 
                                                    test_size=0.5, random_state=1, 
                                                    stratify=requests_data['category_encoded'].to_list())

X_train, X_test, y_train, y_test = train_test_split(X_train,
                                                    y_train, 
                                                    test_size=0.3, random_state=1, 
                                                    stratify=y_train.to_list())

tfidf_train = tfidf.fit_transform(X_train.str.join(" ")).toarray()
tfidf_test = tfidf.transform(X_test.str.join(" ")).toarray()

# %%
knn_model = KNeighborsClassifier(n_neighbors=26, metric='cosine')
knn_model.fit(X=tfidf_train, y=y_train)
predictions = knn_model.predict(tfidf_test)
print("F1 score =  ", f1_score(y_test, predictions, average="micro"))
print(classification_report(y_test, predictions))
# Out:
# F1 score =   0.6453874538745388
#              precision    recall  f1-score   support
#
#           0       0.55      0.11      0.18       104
#           1       0.85      0.91      0.88        95
#           2       0.79      0.29      0.43       194
#           3       0.83      0.25      0.38       117
#           4       0.63      0.96      0.76       985
#           5       0.61      0.85      0.71       471
#           6       0.69      0.17      0.27       149
#           7       0.52      0.41      0.46        81
#           8       0.41      0.69      0.52       189
#           9       0.86      0.66      0.75       124
#          10       0.63      0.91      0.74       182
#          11       0.81      0.26      0.39       167
#          12       0.90      0.20      0.32        96
#          13       0.30      0.21      0.25       112
#          14       0.75      0.78      0.77       332
#          15       0.90      0.44      0.59        97
#          16       0.80      0.51      0.62       165
#          17       0.59      0.21      0.30        78
#          18       0.62      0.64      0.63       117
#          19       0.66      0.84      0.74       300
#          20       0.64      0.24      0.34       148
#          21       0.91      0.61      0.73       101
#          22       0.68      0.59      0.63       182
#          23       0.67      0.25      0.36       196
#          24       0.64      0.79      0.71       545
#          25       0.75      0.35      0.48        93
#
# avg / total       0.67      0.65      0.61      5420

# %% [markdown]
# So we can see increasing of f1 score by 0.05 with using TF-IDF instead of sum of embeddings of all the tokens only on the half of the dataset.

# %% [markdown]
# #### Embeddings of normalized form

# %%
def read_lemmatized_embeddings():
    emgeddings = KeyedVectors.load_word2vec_format("./fiction.cased.lemmatized.word2vec.300d/data", binary=False)
    return emgeddings

lemmatized_embeddings = read_lemmatized_embeddings()

# %%
import pymorphy2

pymorphy = pymorphy2.MorphAnalyzer(lang='uk')

def get_lemmatized_embeddings(s):
    string = " ".join(s)
    words = pymorphy.parse(string)[0].normal_form.split(" ")
    req_words_embeddings=[]
    for word in words:
        # filter out numbers and links
        if re.match(r"^[\d\-\.\#\№\\\/\s]+$", word) or word.startswith("http") or word.startswith("//"):
            continue
        try:
            emb = lemmatized_embeddings.get_vector(word)
            req_words_embeddings.append(emb)
        except:
            continue
    req_words_embeddings = np.array(req_words_embeddings)
    return np.sum(req_words_embeddings, axis=0).reshape(-1)
        

requests_data['request_lemm_embeddings'] = requests_data['cleaned_request'].apply(get_lemmatized_embeddings)

# %%
X_train, X_test, y_train, y_test = train_test_split(requests_data['request_lemm_embeddings'].to_list(), 
                                                    requests_data['category_encoded'].to_list(), 
                                                    test_size=0.3, random_state=1, 
                                                    stratify=requests_data['category_encoded'].to_list())

knn_model = KNeighborsClassifier(n_neighbors=26, metric='cosine')
knn_model.fit(X=X_train, y=y_train)
predictions = knn_model.predict(X_test)
print("F1 score =  ", f1_score(y_test, predictions, average="micro"))
print(classification_report(y_test, predictions))

# %% [markdown]
# I don't know what is the issue, but i've wasted more than severall hours to find the reason of the problem with lemmatized embeddings. The logic is the same, but i receive the problem with shapes. Didn't resolve it, so left as it is because of the lack of time.

# %% [markdown]
# ##### Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

X_train, X_test, y_train, y_test = train_test_split(requests_data['request_embeddings'].to_list(), 
                                                    requests_data['category_encoded'].to_list(), 
                                                    test_size=0.3, random_state=1, 
                                                    stratify=requests_data['category_encoded'].to_list())
lr = LogisticRegression(random_state=0, solver='lbfgs',
                        multi_class='multinomial')
lr.fit(X=X_train, y=y_train)
predictions = lr.predict(X_test)
print("F1 score =  ", f1_score(y_test, predictions, average="micro"))
print(classification_report(y_test, predictions))
# Out:
# F1 score =   0.7163284132841328
#              precision    recall  f1-score   support
#
#           0       0.60      0.57      0.59       209
#           1       0.82      0.90      0.86       191
#           2       0.57      0.57      0.57       388
#           3       0.55      0.49      0.52       234
#           4       0.83      0.85      0.84      1970
#           5       0.75      0.77      0.76       942
#           6       0.59      0.53      0.56       297
#           7       0.49      0.49      0.49       162
#           8       0.60      0.67      0.63       379
#           9       0.81      0.78      0.80       248
#          10       0.74      0.77      0.75       364
#          11       0.68      0.64      0.66       335
#          12       0.62      0.63      0.63       192
#          13       0.39      0.26      0.31       223
#          14       0.84      0.84      0.84       663
#          15       0.76      0.70      0.73       193
#          16       0.77      0.74      0.75       331
#          17       0.51      0.54      0.52       155
#          18       0.71      0.65      0.67       234
#          19       0.74      0.79      0.77       600
#          20       0.49      0.48      0.49       297
#          21       0.83      0.75      0.79       202
#          22       0.75      0.74      0.75       363
#          23       0.59      0.56      0.58       393
#          24       0.72      0.75      0.73      1089
#          25       0.68      0.69      0.68       186
#
# avg / total       0.71      0.72      0.71     10840

# %% [markdown]
# ##### SVM

# %%
from sklearn.svm import LinearSVC

X_train, X_test, y_train, y_test = train_test_split(requests_data['request_embeddings'].to_list(), 
                                                    requests_data['category_encoded'].to_list(), 
                                                    test_size=0.3, random_state=1, 
                                                    stratify=requests_data['category_encoded'].to_list())
svm = LinearSVC(random_state=0, tol=1e-5)
svm.fit(X=X_train, y=y_train)
predictions = svm.predict(X_test)
print("F1 score =  ", f1_score(y_test, predictions, average="micro"))
print(classification_report(y_test, predictions))
# Out:
# F1 score =   0.5593173431734317
#              precision    recall  f1-score   support
#
#           0       0.71      0.08      0.15       209
#           1       0.86      0.73      0.79       191
#           2       0.64      0.12      0.21       388
#           3       0.44      0.48      0.46       234
#           4       0.83      0.67      0.74      1970
#           5       0.35      0.93      0.51       942
#           6       0.53      0.08      0.14       297
#           7       0.42      0.33      0.37       162
#           8       0.52      0.50      0.51       379
#           9       0.86      0.65      0.74       248
#          10       0.78      0.61      0.68       364
#          11       0.76      0.48      0.59       335
#          12       0.59      0.08      0.15       192
#          13       0.37      0.17      0.23       223
#          14       0.84      0.66      0.74       663
#          15       0.76      0.59      0.66       193
#          16       0.73      0.60      0.66       331
#          17       0.57      0.14      0.22       155
#          18       0.70      0.42      0.53       234
#          19       0.69      0.56      0.62       600
#          20       0.35      0.08      0.13       297
#          21       0.84      0.50      0.62       202
#          22       0.62      0.56      0.59       363
#          23       0.34      0.28      0.31       393
#          24       0.42      0.88      0.57      1089
#          25       0.58      0.50      0.54       186
#
# avg / total       0.63      0.56      0.54     10840

# %% [markdown]
# #### Non-linear SVM

# %%
from sklearn.svm import SVC

X_train, X_test, y_train, y_test = train_test_split(requests_data['request_embeddings'].to_list(), 
                                                    requests_data['category_encoded'].to_list(), 
                                                    test_size=0.3, random_state=1, 
                                                    stratify=requests_data['category_encoded'].to_list())
svm = SVC(random_state=0, degree=3, C=3, tol=1e-5)
svm.fit(X=X_train, y=y_train)
predictions = svm.predict(X_test)
print("F1 score =  ", f1_score(y_test, predictions, average="micro"))
print(classification_report(y_test, predictions))
# Out:
# F1 score =   0.3092250922509225
#              precision    recall  f1-score   support
#
#           0       1.00      0.06      0.11       209
#           1       1.00      0.17      0.29       191
#           2       0.97      0.09      0.16       388
#           3       0.98      0.20      0.33       234
#           4       0.21      0.99      0.34      1970
#           5       0.91      0.20      0.33       942
#           6       1.00      0.10      0.18       297
#           7       1.00      0.15      0.26       162
#           8       0.91      0.19      0.31       379
#           9       1.00      0.14      0.25       248
#          10       1.00      0.17      0.29       364
#          11       1.00      0.09      0.16       335
#          12       0.97      0.19      0.32       192
#          13       0.77      0.15      0.25       223
#          14       1.00      0.11      0.20       663
#          15       1.00      0.10      0.19       193
#          16       1.00      0.19      0.32       331
#          17       0.96      0.15      0.27       155
#          18       0.95      0.24      0.39       234
#          19       0.97      0.30      0.46       600
#          20       0.97      0.11      0.20       297
#          21       0.97      0.14      0.25       202
#          22       1.00      0.21      0.35       363
#          23       1.00      0.12      0.21       393
#          24       0.95      0.13      0.23      1089
#          25       0.93      0.08      0.14       186
#
# avg / total       0.83      0.31      0.28     10840

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

X_train, X_test, y_train, y_test = train_test_split(requests_data['request_embeddings'].to_list(), 
                                                    requests_data['category_encoded'].to_list(), 
                                                    test_size=0.3, random_state=1, 
                                                    stratify=requests_data['category_encoded'].to_list())
rf = RandomForestClassifier(n_estimators=100,random_state=0)
rf.fit(X=X_train, y=y_train)
predictions = rf.predict(X_test)
print("F1 score =  ", f1_score(y_test, predictions, average="micro"))
print(classification_report(y_test, predictions))
# Out:
# F1 score =   0.582380073800738
#              precision    recall  f1-score   support
#
#           0       0.54      0.27      0.36       209
#           1       0.88      0.50      0.64       191
#           2       0.62      0.25      0.35       388
#           3       0.94      0.19      0.32       234
#           4       0.56      0.96      0.70      1970
#           5       0.63      0.63      0.63       942
#           6       0.77      0.21      0.33       297
#           7       0.93      0.23      0.37       162
#           8       0.54      0.55      0.54       379
#           9       0.87      0.35      0.50       248
#          10       0.69      0.59      0.64       364
#          11       0.81      0.32      0.46       335
#          12       0.85      0.27      0.41       192
#          13       0.59      0.20      0.30       223
#          14       0.53      0.81      0.64       663
#          15       0.74      0.26      0.39       193
#          16       0.78      0.64      0.70       331
#          17       0.94      0.19      0.32       155
#          18       0.81      0.35      0.49       234
#          19       0.73      0.65      0.69       600
#          20       0.53      0.41      0.46       297
#          21       0.76      0.33      0.46       202
#          22       0.63      0.44      0.52       363
#          23       0.77      0.25      0.38       393
#          24       0.44      0.88      0.59      1089
#          25       0.84      0.17      0.28       186
#
# avg / total       0.65      0.58      0.55     10840

# %% [markdown]
# ### Neural network approach

# %% [markdown]
# #### Feedforward neural net

# %%
from sklearn.neural_network import MLPClassifier

X_train, X_test, y_train, y_test = train_test_split(requests_data['request_embeddings'].to_list(), 
                                                    requests_data['category_encoded'].to_list(), 
                                                    test_size=0.3, random_state=1, 
                                                    stratify=requests_data['category_encoded'].to_list())

mlp = MLPClassifier(solver='adam', alpha=1e-5, learning_rate="adaptive",
                    hidden_layer_sizes=(1000, 100), random_state=1)


mlp.fit(X_train, y_train)
predictions = mlp.predict(X_test)
print("F1 score =  ", f1_score(y_test, predictions, average="micro"))
print(classification_report(y_test, predictions))
# Out:
# F1 score =   0.7125461254612546
#              precision    recall  f1-score   support
#
#           0       0.58      0.54      0.56       209
#           1       0.84      0.83      0.83       191
#           2       0.58      0.59      0.59       388
#           3       0.51      0.62      0.56       234
#           4       0.82      0.87      0.84      1970
#           5       0.76      0.78      0.77       942
#           6       0.63      0.50      0.56       297
#           7       0.47      0.59      0.52       162
#           8       0.65      0.59      0.62       379
#           9       0.73      0.76      0.75       248
#          10       0.73      0.76      0.74       364
#          11       0.71      0.60      0.65       335
#          12       0.59      0.70      0.64       192
#          13       0.46      0.45      0.46       223
#          14       0.80      0.82      0.81       663
#          15       0.65      0.73      0.69       193
#          16       0.81      0.73      0.77       331
#          17       0.60      0.37      0.46       155
#          18       0.78      0.65      0.71       234
#          19       0.77      0.81      0.79       600
#          20       0.50      0.50      0.50       297
#          21       0.66      0.76      0.71       202
#          22       0.74      0.71      0.73       363
#          23       0.54      0.66      0.59       393
#          24       0.78      0.68      0.73      1089
#          25       0.61      0.48      0.54       186
#
# avg / total       0.71      0.71      0.71     10840

# %% [markdown]
# #### LSTM
# classifier template was taken from medium article about multiclass classifier with LSTM:
# https://towardsdatascience.com/multi-class-text-classification-with-lstm-1590bee1bd17

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import Dropout

MAX_NB_WORDS = 50000
MAX_SEQUENCE_LENGTH = 250
EMBEDDING_DIM = 300


tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
tokenizer.fit_on_texts(requests_data['cleaned_request'].str.join(" ").values)
word_index = tokenizer.word_index

X = tokenizer.texts_to_sequences(requests_data['cleaned_request'].str.join(" ").values)
X = pad_sequences(X, maxlen=MAX_SEQUENCE_LENGTH)


Y = pd.get_dummies(requests_data['category']).values


X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.30, random_state = 1)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)


model = Sequential()
model.add(Embedding(MAX_NB_WORDS, EMBEDDING_DIM, input_length=X.shape[1]))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(26, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

epochs = 5
batch_size = 128

history = model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size,validation_split=0.1,callbacks=[EarlyStopping(monitor='val_loss', patience=3, min_delta=0.0001)])

accr = model.evaluate(X_test,Y_test)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0],accr[1]))
# Out:
# (25293, 250) (25293, 26)
# (10840, 250) (10840, 26)
# Train on 22763 samples, validate on 2530 samples
# Epoch 1/5
# 22763/22763 [==============================] - 138s 6ms/step - loss: 2.3406 - acc: 0.3360 - val_loss: 1.6605 - val_acc: 0.4949
# Epoch 2/5
# 22763/22763 [==============================] - 154s 7ms/step - loss: 1.3446 - acc: 0.5710 - val_loss: 1.1209 - val_acc: 0.6292
# Epoch 3/5
# 22763/22763 [==============================] - 151s 7ms/step - loss: 0.9115 - acc: 0.6934 - val_loss: 0.9277 - val_acc: 0.6913
# Epoch 4/5
# 22763/22763 [==============================] - 157s 7ms/step - loss: 0.6400 - acc: 0.7878 - val_loss: 0.8455 - val_acc: 0.7269
# Epoch 5/5
# 22763/22763 [==============================] - 150s 7ms/step - loss: 0.4676 - acc: 0.8453 - val_loss: 0.8277 - val_acc: 0.7387
# 10840/10840 [==============================] - 21s 2ms/step
# Test set
#   Loss: 0.831
#   Accuracy: 0.734

# %% [markdown]
# ### Conclusion

# %% [markdown]
# As result we have next accuracy(f1 score) for different models:
#     - baseline (KNN with sum of embeddings) - 0.59
#     - KNN with TF-IDF document vectors - 0.64
#     - KNN with sum of lemmatized embeddings - (had errors with it)
#     - Logistic regression with sum of embeddings - 0.71
#     - Linear SVM - 0.55
#     - Non-Linear SVM (degree = 3) - 0.3
#     - Random Forest - 0.58
#     - FeedForward network - 0.71
#     - LSTM - 0.734
#
# Next improvements, which can be done is to fix lemmatized embeddings sum usage as a feature vector, also to combine different vectors (simple embeddings, normalized embeddings, tf-idf vectors) with models we used to find the best accuracy and also use cross-validation to find the best hyperparameters for every model.
#
# Also it would be good to try BiLSTM in our case and also make some experiments with different network topologies.
